# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/train.csv')
df_test = pd.read_csv('data/test.csv')

# %%
df
# Out:
#        row_id        date  country       store         product  num_sold
# 0           0  2015-01-01  Finland  KaggleMart      Kaggle Mug       329
# 1           1  2015-01-01  Finland  KaggleMart      Kaggle Hat       520
# 2           2  2015-01-01  Finland  KaggleMart  Kaggle Sticker       146
# 3           3  2015-01-01  Finland  KaggleRama      Kaggle Mug       572
# 4           4  2015-01-01  Finland  KaggleRama      Kaggle Hat       911
# ...       ...         ...      ...         ...             ...       ...
# 26293   26293  2018-12-31   Sweden  KaggleMart      Kaggle Hat       823
# 26294   26294  2018-12-31   Sweden  KaggleMart  Kaggle Sticker       250
# 26295   26295  2018-12-31   Sweden  KaggleRama      Kaggle Mug      1004
# 26296   26296  2018-12-31   Sweden  KaggleRama      Kaggle Hat      1441
# 26297   26297  2018-12-31   Sweden  KaggleRama  Kaggle Sticker       388
#
# [26298 rows x 6 columns]

# %% [markdown]
# # Feature Engineering

# %%
def get_features(df):
    df['date'] = pd.to_datetime(df['date'])
    df['day of week'] = df['date'].dt.day_name()
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year
    df = pd.get_dummies(df_test, columns=['country', 'store', 'product', 'day of week'])
    
    return df

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['day of week'] = df['date'].dt.day_name()
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year

# %%
df
# Out:
#        row_id       date  country       store         product  num_sold  \
# 0           0 2015-01-01  Finland  KaggleMart      Kaggle Mug       329
# 1           1 2015-01-01  Finland  KaggleMart      Kaggle Hat       520
# 2           2 2015-01-01  Finland  KaggleMart  Kaggle Sticker       146
# 3           3 2015-01-01  Finland  KaggleRama      Kaggle Mug       572
# 4           4 2015-01-01  Finland  KaggleRama      Kaggle Hat       911
# ...       ...        ...      ...         ...             ...       ...
# 26293   26293 2018-12-31   Sweden  KaggleMart      Kaggle Hat       823
# 26294   26294 2018-12-31   Sweden  KaggleMart  Kaggle Sticker       250
# 26295   26295 2018-12-31   Sweden  KaggleRama      Kaggle Mug      1004
# 26296   26296 2018-12-31   Sweden  KaggleRama      Kaggle Hat      1441
# 26297   26297 2018-12-31   Sweden  KaggleRama  Kaggle Sticker       388
#
#       day of week  month  year
# 0        Thursday      1  2015
# 1        Thursday      1  2015
# 2        Thursday      1  2015
# 3        Thursday      1  2015
# 4        Thursday      1  2015
# ...           ...    ...   ...
# 26293      Monday     12  2018
# 26294      Monday     12  2018
# 26295      Monday     12  2018
# 26296      Monday     12  2018
# 26297      Monday     12  2018
#
# [26298 rows x 9 columns]

# %% [markdown]
# # Analysis

# %%
df['product'].value_counts()
# Out:
# Kaggle Mug        8766
# Kaggle Sticker    8766
# Kaggle Hat        8766
# Name: product, dtype: int64

# %%
sns.boxplot(x=df['product'], y=df['num_sold'])
# Out:
# <AxesSubplot:xlabel='product', ylabel='num_sold'>

# %%
sns.boxplot(x=df['store'], y=df['num_sold'])
# Out:
# <AxesSubplot:xlabel='store', ylabel='num_sold'>

# %%
sns.boxplot(x=df['country'], y=df['num_sold'])
# Out:
# <AxesSubplot:xlabel='country', ylabel='num_sold'>

# %%
sns.boxplot(x=df['year'], y=df['num_sold'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='num_sold'>

# %%
sns.boxplot(x=df['day of week'], y=df['num_sold'])
# Out:
# <AxesSubplot:xlabel='day of week', ylabel='num_sold'>

# %%
sns.boxplot(x=df['month'], y=df['num_sold'])
# Out:
# <AxesSubplot:xlabel='month', ylabel='num_sold'>

# %%
df_store = df.groupby(['store']).agg('mean')
print(df_store)
# Out:
#              row_id    num_sold
# store
# KaggleMart  13147.0  282.558978
# KaggleRama  13150.0  492.508176

# %%
plt.bar(df_store.index, df_store['num_sold'])
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# # Mutual Information

# %%
from sklearn.feature_selection import mutual_info_classif, mutual_info_regression

# %%
df_encode = pd.get_dummies(df, columns=['country', 'store', 'product', 'day of week'])
df_encode.columns
# Out:
# Index(['row_id', 'date', 'num_sold', 'month', 'year', 'country_Finland',
#        'country_Norway', 'country_Sweden', 'store_KaggleMart',
#        'store_KaggleRama', 'product_Kaggle Hat', 'product_Kaggle Mug',
#        'product_Kaggle Sticker', 'day of week_Friday', 'day of week_Monday',
#        'day of week_Saturday', 'day of week_Sunday', 'day of week_Thursday',
#        'day of week_Tuesday', 'day of week_Wednesday'],
#       dtype='object')

# %%
X_encode = df_encode.drop(columns=['date', 'num_sold', 'row_id'])
y_encode = df_encode['num_sold']

# %%
mi_values = mutual_info_regression(X_encode, y_encode, discrete_features=True)

# %%
mi_dict = {}

for i in range(len(X_encode.columns)):
    mi_dict[X_encode.columns[i]] = mi_values[i]

# %%
mi_dict
# Out:
# {'month': 0.03382166834833278,
#  'year': 0.020978281688475597,
#  'country_Finland': 0.04671207457521254,
#  'country_Norway': 0.0898848369411207,
#  'country_Sweden': 0.032944528266991124,
#  'store_KaggleMart': 0.13254568520260768,
#  'store_KaggleRama': 0.13254568520260768,
#  'product_Kaggle Hat': 0.28718978400328377,
#  'product_Kaggle Mug': 0.1040629982444159,
#  'product_Kaggle Sticker': 0.33767859153237145,
#  'day of week_Friday': 0.0,
#  'day of week_Monday': 0.00025899784217653377,
#  'day of week_Saturday': 0.013276680962430953,
#  'day of week_Sunday': 0.019195585803922555,
#  'day of week_Thursday': 0.003130507274004879,
#  'day of week_Tuesday': 0.0,
#  'day of week_Wednesday': 0.004459219082205701}

# %%
df_encode.corr()
# Out:
#                               row_id  num_sold  country_Finland  \
# row_id                  1.000000e+00  0.068253    -5.588615e-04
# num_sold                6.825262e-02  1.000000    -2.171278e-01
# country_Finland        -5.588615e-04 -0.217128     1.000000e+00
# country_Norway         -2.734879e-18  0.305470    -5.000000e-01
# country_Sweden          5.588615e-04 -0.088342    -5.000000e-01
# store_KaggleMart       -1.975874e-04 -0.394536    -4.477790e-20
# store_KaggleRama        1.975874e-04  0.394536     4.477790e-20
# product_Kaggle Hat      0.000000e+00  0.641309     0.000000e+00
# product_Kaggle Mug     -9.314358e-05 -0.088172     0.000000e+00
# product_Kaggle Sticker  9.314358e-05 -0.553137     0.000000e+00
#
#                         country_Norway  country_Sweden  store_KaggleMart  \
# row_id                   -2.734879e-18    5.588615e-04     -1.975874e-04
# num_sold                  3.054697e-01   -8.834193e-02     -3.945358e-01
# country_Finland          -5.000000e-01   -5.000000e-01     -4.477790e-20
# country_Norway            1.000000e+00   -5.000000e-01     -4.477790e-20
# country_Sweden           -5.000000e-01    1.000000e+00     -3.582232e-20
# store_KaggleMart         -4.477790e-20   -3.582232e-20      1.000000e+00
# store_KaggleRama          4.477790e-20    3.582232e-20     -1.000000e+00
# product_Kaggle Hat        0.000000e+00    0.000000e+00      0.000000e+00
# product_Kaggle Mug        0.000000e+00    0.000000e+00      0.000000e+00
# product_Kaggle Sticker    0.000000e+00    0.000000e+00      0.000000e+00
#
#                         store_KaggleRama  product_Kaggle Hat  \
# row_id                      1.975874e-04            0.000000
# num_sold                    3.945358e-01            0.641309
# country_Finland             4.477790e-20            0.000000
# country_Norway              4.477790e-20            0.000000
# country_Sweden              3.582232e-20            0.000000
# store_KaggleMart           -1.000000e+00            0.000000
# store_KaggleRama            1.000000e+00            0.000000
# product_Kaggle Hat          0.000000e+00            1.000000
# product_Kaggle Mug          0.000000e+00           -0.500000
# product_Kaggle Sticker      0.000000e+00           -0.500000
#
#                         product_Kaggle Mug  product_Kaggle Sticker
# row_id                           -0.000093                0.000093
# num_sold                         -0.088172               -0.553137
# country_Finland                   0.000000                0.000000
# country_Norway                    0.000000                0.000000
# country_Sweden                    0.000000                0.000000
# store_KaggleMart                  0.000000                0.000000
# store_KaggleRama                  0.000000                0.000000
# product_Kaggle Hat               -0.500000               -0.500000
# product_Kaggle Mug                1.000000               -0.500000
# product_Kaggle Sticker           -0.500000                1.000000

# %%
sns.heatmap(df_encode.corr())
# Out:
# <AxesSubplot:>

# %%
features = ['store_KaggleMart',
            'store_KaggleRama',
            'product_Kaggle Hat',
            'product_Kaggle Mug',
            'product_Kaggle Sticker',
            'country_Norway']

df_train_final = df_encode[features]

# %%
features = ['row_id',
            'store_KaggleMart',
            'store_KaggleRama',
            'product_Kaggle Hat',
            'product_Kaggle Mug',
            'product_Kaggle Sticker',
            'country_Norway',]

df_test_encode = get_features(df_test)
df_test_final = df_test_encode[features]

# %%
df_train_final.to_csv('Final Train.csv', index=False)
df_test_final.to_csv('Final Test.csv', index=False)
