# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from sklearn.feature_selection import f_classif, mutual_info_regression
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('data/train.csv')
df_test = pd.read_csv('data/test.csv')

# %%
df
# Out:
#        row_id        date  country       store         product  num_sold
# 0           0  2015-01-01  Finland  KaggleMart      Kaggle Mug       329
# 1           1  2015-01-01  Finland  KaggleMart      Kaggle Hat       520
# 2           2  2015-01-01  Finland  KaggleMart  Kaggle Sticker       146
# 3           3  2015-01-01  Finland  KaggleRama      Kaggle Mug       572
# 4           4  2015-01-01  Finland  KaggleRama      Kaggle Hat       911
# ...       ...         ...      ...         ...             ...       ...
# 26293   26293  2018-12-31   Sweden  KaggleMart      Kaggle Hat       823
# 26294   26294  2018-12-31   Sweden  KaggleMart  Kaggle Sticker       250
# 26295   26295  2018-12-31   Sweden  KaggleRama      Kaggle Mug      1004
# 26296   26296  2018-12-31   Sweden  KaggleRama      Kaggle Hat      1441
# 26297   26297  2018-12-31   Sweden  KaggleRama  Kaggle Sticker       388
#
# [26298 rows x 6 columns]

# %% [markdown]
# # Feature Engineering

# %%
def get_year_day(x):
    
    if (x.is_leap_year) & (x >= dt.datetime(x.year, 4, 29)):
        
        return x.dayofyear - 1
    else:
        return x.dayofyear

# %%
def get_features(df):
    df['date'] = pd.to_datetime(df['date'])
    df['day of week'] = df['date'].dt.day_name()
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year
    df['day of year'] = df['date'].apply(lambda x: get_year_day(x))
    df = pd.get_dummies(df_test, columns=['country', 'store', 'product', 'day of week'])
    
    return df

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['day of week'] = df['date'].dt.day_name()
df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year

# %%
df['day of year'] = df['date'].apply(lambda x: get_year_day(x))

# %%
len(df.index)
# Out:
# 26298

# %%
df = df[df['date'] != dt.datetime(2016, 4, 29)]

# %%
len(df.index)
# Out:
# 26280

# %%
df['day of year'].value_counts()
# Out:
# 351    72
# 356    72
# 21     72
# 37     72
# 53     72
#        ..
# 250    72
# 266    72
# 282    72
# 298    72
# 16     72
# Name: day of year, Length: 365, dtype: int64

# %% [markdown]
# # Analysis

# %%
def get_classif(independent, dependent):
    
    dep_array = dependent.array
    
    le = LabelEncoder()
    le.fit(independent)
    temp_encode = le.transform(independent).reshape(-1,1)
    f_val, p_val = f_classif(temp_encode[0:199], dep_array[0:199])
    
    return f_val, p_val

# %%
def get_mi_reg(independent, dependent):
    
    dep_array = dependent.array
    
    le = LabelEncoder()
    le.fit(independent)
    temp_encode = le.transform(independent).reshape(-1,1)
    p_val = mutual_info_regression(temp_encode, dep_array)
    
    return p_val

# %%
df['product'].value_counts()
# Out:
# Kaggle Sticker    8760
# Kaggle Mug        8760
# Kaggle Hat        8760
# Name: product, dtype: int64

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.lineplot(df['date'], df['num_sold'])
# Out:
# /Users/marcwork/Library/Python/3.8/lib/python/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='date', ylabel='num_sold'>

# %%
sns.distplot(np.log(df['num_sold']))
# Out:
# /Users/marcwork/Library/Python/3.8/lib/python/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='num_sold', ylabel='Density'>

# %%
sns.lineplot(df['day of year'], df['num_sold'], hue=df['product'])
# Out:
# /Users/marcwork/Library/Python/3.8/lib/python/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='day of year', ylabel='num_sold'>

# %%
sns.boxplot(x=df['product'], y=np.log(df['num_sold']))
get_classif(df['product'], np.log(df['num_sold']))
#get_mi_reg(df['product'], df['num_sold'])
# Out:
# (array([2.35955056]), array([0.01380712]))

# %%
sns.boxplot(x=df['store'], y=np.log(df['num_sold']))
#get_mi_reg(df['store'], df['num_sold'])
get_classif(df['store'], np.log(df['num_sold']))
# Out:
# (array([0.79408583]), array([0.78775023]))

# %%
sns.boxplot(x=df['country'], y=np.log(df['num_sold']))
get_classif(df['country'], np.log(df['num_sold']))
#get_mi_reg(df['country'], df['num_sold'])
# Out:
# (array([0.84146528]), array([0.73111368]))

# %%
sns.boxplot(x=df['year'], y=df['num_sold'])
get_classif(df['year'], df['num_sold'])
#get_mi_reg(df['year'], df['num_sold'])
# Out:
# /usr/local/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /usr/local/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# (array([nan]), array([nan]))

# %%
sns.boxplot(x=df['day of week'], y=np.log(df['num_sold']))
get_classif(df['day of week'], np.log(df['num_sold']))
#get_mi_reg(df['day of week'], df['num_sold'])
# Out:
# (array([0.58528835]), array([0.96451877]))

# %%
sns.boxplot(x=df['month'], y=df['num_sold'])
get_classif(df['month'], np.log(df['num_sold']))
# Out:
# /usr/local/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:114: UserWarning: Features [0] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx,
# /usr/local/lib/python3.8/site-packages/sklearn/feature_selection/_univariate_selection.py:116: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# (array([nan]), array([nan]))

# %%
df_store = df.groupby(['store']).agg('mean')
print(df_store)
# Out:
#                   row_id    num_sold     month    year  day of year
# store
# KaggleMart  13150.032877  282.566895  6.524658  2016.5        183.0
# KaggleRama  13153.032877  492.523212  6.524658  2016.5        183.0

# %%
plt.bar(df_store.index, df_store['num_sold'])
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# # Mutual Information

# %%
from sklearn.feature_selection import mutual_info_classif, mutual_info_regression

# %%
df_encode = pd.get_dummies(df, columns=['country', 'store', 'product', 'day of week'])
df_encode.columns
# Out:
# Index(['row_id', 'date', 'num_sold', 'month', 'year', 'day of year',
#        'country_Finland', 'country_Norway', 'country_Sweden',
#        'store_KaggleMart', 'store_KaggleRama', 'product_Kaggle Hat',
#        'product_Kaggle Mug', 'product_Kaggle Sticker', 'day of week_Friday',
#        'day of week_Monday', 'day of week_Saturday', 'day of week_Sunday',
#        'day of week_Thursday', 'day of week_Tuesday', 'day of week_Wednesday'],
#       dtype='object')

# %%
X_encode = df_encode.drop(columns=['date', 'num_sold', 'row_id'])
y_encode = df_encode['num_sold']

# %%
mi_values = mutual_info_regression(X_encode, y_encode, discrete_features=True)

# %%
mi_dict = {}

for i in range(len(X_encode.columns)):
    mi_dict[X_encode.columns[i]] = mi_values[i]

# %%
mi_dict
# Out:
# {'month': 0.03396211866731136,
#  'year': 0.029216481561110008,
#  'day of year': 0.0,
#  'country_Finland': 0.04475600598963192,
#  'country_Norway': 0.08661518712074368,
#  'country_Sweden': 0.037471075653242814,
#  'store_KaggleMart': 0.1348262512062599,
#  'store_KaggleRama': 0.1348262512062599,
#  'product_Kaggle Hat': 0.2903150964781027,
#  'product_Kaggle Mug': 0.10948109453055288,
#  'product_Kaggle Sticker': 0.34048332108138046,
#  'day of week_Friday': 0.0027211842959087296,
#  'day of week_Monday': 2.920738508094267e-05,
#  'day of week_Saturday': 0.016411820361169616,
#  'day of week_Sunday': 0.012338964739347702,
#  'day of week_Thursday': 0.0029689293882131373,
#  'day of week_Tuesday': 0.002710166679544157,
#  'day of week_Wednesday': 0.0050112899639338515}

# %%
df_encode.corr()
# Out:
#                               row_id  num_sold         month          year  \
# row_id                  1.000000e+00  0.068258  2.492972e-01  9.682461e-01
# num_sold                6.825826e-02  1.000000 -7.573232e-02  8.952721e-02
# month                   2.492972e-01 -0.075732  1.000000e+00  1.776099e-04
# year                    9.682461e-01  0.089527  1.776099e-04  1.000000e+00
# day of year             2.499971e-01 -0.074007  9.965049e-01  0.000000e+00
# country_Finland        -5.587353e-04 -0.217126  5.165146e-18 -1.167072e-17
# country_Norway         -2.736134e-18  0.305487 -2.733267e-18  0.000000e+00
# country_Sweden          5.587353e-04 -0.088361 -8.729825e-19  0.000000e+00
# store_KaggleMart       -1.975427e-04 -0.394547  0.000000e+00  0.000000e+00
# store_KaggleRama        1.975427e-04  0.394547  0.000000e+00  0.000000e+00
# product_Kaggle Hat     -1.933663e-20  0.641203  6.287552e-18  0.000000e+00
# product_Kaggle Mug     -9.312254e-05 -0.088080  6.287552e-18  0.000000e+00
# product_Kaggle Sticker  9.312254e-05 -0.553123  6.297945e-18  0.000000e+00
# day of week_Friday      9.074134e-06 -0.012411  4.949662e-04 -1.086679e-16
# day of week_Monday      1.774579e-03 -0.045568 -3.205420e-03  2.623823e-03
# day of week_Saturday   -1.632560e-04  0.096400  2.464453e-03 -8.746075e-04
# day of week_Sunday      8.056616e-04  0.093901  1.965038e-04  8.746075e-04
# day of week_Thursday   -2.101091e-03 -0.040546  1.897466e-03 -2.623823e-03
# day of week_Tuesday    -6.459052e-04 -0.046946 -2.913763e-03  9.768438e-17
# day of week_Wednesday   3.203055e-04 -0.045039  1.063088e-03 -9.638711e-17
#
#                          day of year  country_Finland  country_Norway  \
# row_id                  2.499971e-01    -5.587353e-04   -2.736134e-18
# num_sold               -7.400744e-02    -2.171257e-01    3.054870e-01
# month                   9.965049e-01     5.165146e-18   -2.733267e-18
# year                    0.000000e+00    -1.167072e-17    0.000000e+00
# day of year             1.000000e+00    -1.251983e-18    7.076424e-19
# country_Finland        -1.251983e-18     1.000000e+00   -5.000000e-01
# country_Norway          7.076424e-19    -5.000000e-01    1.000000e+00
# country_Sweden         -2.852343e-18    -5.000000e-01   -5.000000e-01
# store_KaggleMart        0.000000e+00    -4.480857e-20   -4.480857e-20
# store_KaggleRama        0.000000e+00     4.480857e-20    4.480857e-20
# product_Kaggle Hat      0.000000e+00     0.000000e+00    0.000000e+00
# product_Kaggle Mug      0.000000e+00     0.000000e+00    0.000000e+00
# product_Kaggle Sticker  0.000000e+00     0.000000e+00    0.000000e+00
# day of week_Friday      3.719594e-05     4.271867e-17    6.730378e-20
# day of week_Monday     -3.062538e-03    -2.128950e-17    0.000000e+00
# day of week_Saturday    2.728443e-03    -2.133748e-17    5.437523e-20
# day of week_Sunday     -1.670475e-04    -2.131189e-17   -2.238980e-20
# day of week_Thursday    1.763280e-03    -2.128630e-17    3.198543e-21
# day of week_Tuesday    -2.585118e-03     4.271867e-17    1.314026e-19
# day of week_Wednesday   1.283260e-03     4.271867e-17    4.166424e-20
#
#                         country_Sweden  store_KaggleMart  store_KaggleRama  \
# row_id                    5.587353e-04     -1.975427e-04      1.975427e-04
# num_sold                 -8.836132e-02     -3.945467e-01      3.945467e-01
# month                    -8.729825e-19      0.000000e+00      0.000000e+00
# year                      0.000000e+00      0.000000e+00      0.000000e+00
# day of year              -2.852343e-18      0.000000e+00      0.000000e+00
# country_Finland          -5.000000e-01     -4.480857e-20      4.480857e-20
# country_Norway           -5.000000e-01     -4.480857e-20      4.480857e-20
# country_Sweden            1.000000e+00     -3.584686e-20      3.584686e-20
# store_KaggleMart         -3.584686e-20      1.000000e+00     -1.000000e+00
# store_KaggleRama          3.584686e-20     -1.000000e+00      1.000000e+00
# product_Kaggle Hat        0.000000e+00      0.000000e+00      0.000000e+00
# product_Kaggle Mug        0.000000e+00      0.000000e+00      0.000000e+00
# product_Kaggle Sticker    0.000000e+00      0.000000e+00      0.000000e+00
# day of week_Friday        4.243984e-17     -3.021648e-20      3.021648e-20
# day of week_Monday       -2.134068e-17      2.412492e-20     -2.412492e-20
# day of week_Saturday     -2.129590e-17      2.412492e-20     -2.412492e-20
# day of week_Sunday       -2.137266e-17      2.412492e-20     -2.412492e-20
# day of week_Thursday     -2.134708e-17      2.412492e-20     -2.412492e-20
# day of week_Tuesday       4.256804e-17     -3.021648e-20      3.021648e-20
# day of week_Wednesday     4.238856e-17     -3.021648e-20      3.021648e-20
#
#                         product_Kaggle Hat  product_Kaggle Mug  \
# row_id                       -1.933663e-20       -9.312254e-05
# num_sold                      6.412028e-01       -8.808009e-02
# month                         6.287552e-18        6.287552e-18
# year                          0.000000e+00        0.000000e+00
# day of year                   0.000000e+00        0.000000e+00
# country_Finland               0.000000e+00        0.000000e+00
# country_Norway                0.000000e+00        0.000000e+00
# country_Sweden                0.000000e+00        0.000000e+00
# store_KaggleMart              0.000000e+00        0.000000e+00
# store_KaggleRama              0.000000e+00        0.000000e+00
# product_Kaggle Hat            1.000000e+00       -5.000000e-01
# product_Kaggle Mug           -5.000000e-01        1.000000e+00
# product_Kaggle Sticker       -5.000000e-01       -5.000000e-01
# day of week_Friday            7.916207e-18        1.053144e-17
# day of week_Monday            8.073123e-18        1.072152e-17
# day of week_Saturday          8.085917e-18        1.073431e-17
# day of week_Sunday            8.079520e-18        1.070232e-17
# day of week_Thursday          8.085917e-18        1.069593e-17
# day of week_Tuesday           7.909797e-18        1.052503e-17
# day of week_Wednesday         7.929026e-18        1.054426e-17
#
#                         product_Kaggle Sticker  day of week_Friday  \
# row_id                            9.312254e-05        9.074134e-06
# num_sold                         -5.531227e-01       -1.241092e-02
# month                             6.297945e-18        4.949662e-04
# year                              0.000000e+00       -1.086679e-16
# day of year                       0.000000e+00        3.719594e-05
# country_Finland                   0.000000e+00        4.271867e-17
# country_Norway                    0.000000e+00        6.730378e-20
# country_Sweden                    0.000000e+00        4.243984e-17
# store_KaggleMart                  0.000000e+00       -3.021648e-20
# store_KaggleRama                  0.000000e+00        3.021648e-20
# product_Kaggle Hat               -5.000000e-01        7.916207e-18
# product_Kaggle Mug               -5.000000e-01        1.053144e-17
# product_Kaggle Sticker            1.000000e+00        1.050580e-17
# day of week_Friday                1.050580e-17        1.000000e+00
# day of week_Monday                1.069593e-17       -1.665996e-01
# day of week_Saturday              1.070872e-17       -1.665996e-01
# day of week_Sunday                1.072791e-17       -1.665996e-01
# day of week_Thursday              1.072152e-17       -1.665996e-01
# day of week_Tuesday               1.055067e-17       -1.661342e-01
# day of week_Wednesday             1.056990e-17       -1.661342e-01
#
#                         day of week_Monday  day of week_Saturday  \
# row_id                        1.774579e-03         -1.632560e-04
# num_sold                     -4.556801e-02          9.640020e-02
# month                        -3.205420e-03          2.464453e-03
# year                          2.623823e-03         -8.746075e-04
# day of year                  -3.062538e-03          2.728443e-03
# country_Finland              -2.128950e-17         -2.133748e-17
# country_Norway                0.000000e+00          5.437523e-20
# country_Sweden               -2.134068e-17         -2.129590e-17
# store_KaggleMart              2.412492e-20          2.412492e-20
# store_KaggleRama             -2.412492e-20         -2.412492e-20
# product_Kaggle Hat            8.073123e-18          8.085917e-18
# product_Kaggle Mug            1.072152e-17          1.073431e-17
# product_Kaggle Sticker        1.069593e-17          1.070872e-17
# day of week_Friday           -1.665996e-01         -1.665996e-01
# day of week_Monday            1.000000e+00         -1.670663e-01
# day of week_Saturday         -1.670663e-01          1.000000e+00
# day of week_Sunday           -1.670663e-01         -1.670663e-01
# day of week_Thursday         -1.670663e-01         -1.670663e-01
# day of week_Tuesday          -1.665996e-01         -1.665996e-01
# day of week_Wednesday        -1.665996e-01         -1.665996e-01
#
#                         day of week_Sunday  day of week_Thursday  \
# row_id                        8.056616e-04         -2.101091e-03
# num_sold                      9.390114e-02         -4.054621e-02
# month                         1.965038e-04          1.897466e-03
# year                          8.746075e-04         -2.623823e-03
# day of year                  -1.670475e-04          1.763280e-03
# country_Finland              -2.131189e-17         -2.128630e-17
# country_Norway               -2.238980e-20          3.198543e-21
# country_Sweden               -2.137266e-17         -2.134708e-17
# store_KaggleMart              2.412492e-20          2.412492e-20
# store_KaggleRama             -2.412492e-20         -2.412492e-20
# product_Kaggle Hat            8.079520e-18          8.085917e-18
# product_Kaggle Mug            1.070232e-17          1.069593e-17
# product_Kaggle Sticker        1.072791e-17          1.072152e-17
# day of week_Friday           -1.665996e-01         -1.665996e-01
# day of week_Monday           -1.670663e-01         -1.670663e-01
# day of week_Saturday         -1.670663e-01         -1.670663e-01
# day of week_Sunday            1.000000e+00         -1.670663e-01
# day of week_Thursday         -1.670663e-01          1.000000e+00
# day of week_Tuesday          -1.665996e-01         -1.665996e-01
# day of week_Wednesday        -1.665996e-01         -1.665996e-01
#
#                         day of week_Tuesday  day of week_Wednesday
# row_id                        -6.459052e-04           3.203055e-04
# num_sold                      -4.694606e-02          -4.503856e-02
# month                         -2.913763e-03           1.063088e-03
# year                           9.768438e-17          -9.638711e-17
# day of year                   -2.585118e-03           1.283260e-03
# country_Finland                4.271867e-17           4.271867e-17
# country_Norway                 1.314026e-19           4.166424e-20
# country_Sweden                 4.256804e-17           4.238856e-17
# store_KaggleMart              -3.021648e-20          -3.021648e-20
# store_KaggleRama               3.021648e-20           3.021648e-20
# product_Kaggle Hat             7.909797e-18           7.929026e-18
# product_Kaggle Mug             1.052503e-17           1.054426e-17
# product_Kaggle Sticker         1.055067e-17           1.056990e-17
# day of week_Friday            -1.661342e-01          -1.661342e-01
# day of week_Monday            -1.665996e-01          -1.665996e-01
# day of week_Saturday          -1.665996e-01          -1.665996e-01
# day of week_Sunday            -1.665996e-01          -1.665996e-01
# day of week_Thursday          -1.665996e-01          -1.665996e-01
# day of week_Tuesday            1.000000e+00          -1.661342e-01
# day of week_Wednesday         -1.661342e-01           1.000000e+00

# %%
sns.heatmap(df_encode.corr())
# Out:
# <AxesSubplot:>

# %%
features = ['store_KaggleMart',
            'store_KaggleRama',
            'product_Kaggle Hat',
            'product_Kaggle Mug',
            'product_Kaggle Sticker',
            'country_Norway',
            'num_sold']

df_train_final = df_encode

# %%
features = ['row_id',
            'store_KaggleMart',
            'store_KaggleRama',
            'product_Kaggle Hat',
            'product_Kaggle Mug',
            'product_Kaggle Sticker',
            'country_Norway',]

df_test_encode = get_features(df_test)
df_test_final = df_test_encode

# %%
df_train_final.to_csv('Final Train.csv', index=False)
df_test_final.to_csv('Final Test.csv', index=False)
